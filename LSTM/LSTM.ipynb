# %%
import os
import numpy as np
import pyedflib
from scipy.stats import zscore
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import classification_report

# %%
# 설정
sampling_rate = 256
segment_length = 30 * sampling_rate  # 30초 = 7680포인트

label_map = {
    'Sleep stage W': 0,
    'Sleep stage N1': 1,
    'Sleep stage N2': 1,
    'Sleep stage N3': 2,
    'Sleep stage R': 3
}

def load_ecg_and_labels(sn_id, root_dir):
    base = f"SN{int(sn_id):03d}"
    ecg_path = os.path.join(root_dir, f"{base}.edf")
    label_path = os.path.join(root_dir, f"{base}_sleepscoring.edf")
    
    if not os.path.exists(ecg_path) or not os.path.exists(label_path):
        print(f"❌ 파일 없음: {base}")
        return [], []

    with pyedflib.EdfReader(ecg_path) as ecg_reader:
        ecg_signal = ecg_reader.readSignal(7)

    with pyedflib.EdfReader(label_path) as label_reader:
        onsets, durations, labels = label_reader.readAnnotations()

    segments, segment_labels = [], []

    for onset, duration, label in zip(onsets, durations, labels):
        label_str = label.decode() if isinstance(label, bytes) else label
        if label_str not in label_map:
            continue  # 'Lights on/off' 무시

        start = int(onset * sampling_rate)
        num_segments = int(duration // 30)

        for i in range(num_segments):
            seg_start = start + i * segment_length
            seg_end = seg_start + segment_length
            if seg_end > len(ecg_signal):
                break

            segment = ecg_signal[seg_start:seg_end]
            segment = zscore(segment)
            segments.append(segment.astype(np.float32))
            segment_labels.append(label_map[label_str])

    return segments, segment_labels

def create_sequences(segments, labels, seq_len=10):
    X, y = [], []
    for i in range(len(segments) - seq_len + 1):
        X.append(np.stack(segments[i:i+seq_len]))
        y.append(labels[i + seq_len - 1])
    return np.array(X), np.array(y)

# %%
class SleepDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.long)
    
    def __len__(self):
        return len(self.X)
    
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# %%
class SleepLSTM(nn.Module):
    def __init__(self, input_size=7680, hidden_size=128, num_layers=2, num_classes=4):
        super(SleepLSTM, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, num_classes)
    
    def forward(self, x):
        out, _ = self.lstm(x)
        out = out[:, -1, :]
        return self.fc(out)

# %%
def train_model(model, loader, epochs=10, lr=0.0001, device='cuda' if torch.cuda.is_available() else 'cpu'):
    model.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    criterion = nn.CrossEntropyLoss()

    for epoch in range(epochs):
        model.train()
        total_loss, correct, total = 0, 0, 0

        for X_batch, y_batch in loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            optimizer.zero_grad()
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)
            loss.backward()
            optimizer.step()

            total_loss += loss.item()
            correct += (outputs.argmax(1) == y_batch).sum().item()
            total += y_batch.size(0)

        acc = correct / total if total > 0 else 0
        print(f"Epoch [{epoch+1}/{epochs}] Loss: {total_loss:.4f} Acc: {acc:.4f}")

from sklearn.metrics import classification_report

def evaluate_one_person(model, loader, device='cuda' if torch.cuda.is_available() else 'cpu'):
    model = model.to(device)
    model.eval()
    all_preds, all_labels = [], []

    with torch.no_grad():
        for X_batch, y_batch in loader:
            X_batch = X_batch.to(device)
            outputs = model(X_batch)
            preds = outputs.argmax(1).cpu().numpy()
            all_preds.extend(preds)
            all_labels.extend(y_batch.numpy())

    # labels 인자를 추가!
    print(classification_report(
        all_labels, all_preds, 
        labels=[0,1,2,3],  # 모든 클래스 포함
        target_names=["W", "N1/2", "N3", "R"],
        zero_division=0    # division by zero 경고 안 뜨게
    ))

# %%
# 데이터 로드 및 분리
root_dir = "/home/mhb0917/캡스톤디자인/sleep/recordings"
seq_len = 10

train_X, train_y = [], []
val_data, test_data = {}, {}

for i in range(1, 155):
    segments, labels = load_ecg_and_labels(i, root_dir)
    if segments:
        X_seq, y_seq = create_sequences(segments, labels, seq_len)
        if 1 <= i <= 93:
            train_X.append(X_seq)
            train_y.append(y_seq)
        elif 94 <= i <= 123:
            val_data[f"SN{i:03d}"] = (X_seq, y_seq)
        else:
            test_data[f"SN{i:03d}"] = (X_seq, y_seq)

train_X = np.concatenate(train_X)
train_y = np.concatenate(train_y)

# 학습
train_dataset = SleepDataset(train_X, train_y)
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
# Out:
# ❌ 파일 없음: SN014
# ❌ 파일 없음: SN064
# ❌ 파일 없음: SN135
# Epoch [1/10] Loss: nan Acc: 0.1619
# Epoch [2/10] Loss: nan Acc: 0.1616
# Epoch [3/10] Loss: nan Acc: 0.1616
# Epoch [4/10] Loss: nan Acc: 0.1616
# Epoch [5/10] Loss: nan Acc: 0.1616
# Epoch [6/10] Loss: nan Acc: 0.1616
# Epoch [7/10] Loss: nan Acc: 0.1616
# Epoch [8/10] Loss: nan Acc: 0.1616
# Epoch [9/10] Loss: nan Acc: 0.1616
# Epoch [10/10] Loss: nan Acc: 0.1616
#
# 📊 Validation Results:
#
# 🧪 Evaluation for SN094
#               precision    recall  f1-score   support
#
#            W       0.07      1.00      0.13        70
#         N1/2       0.00      0.00      0.00       604
#           N3       0.00      0.00      0.00       202
#            R       0.00      0.00      0.00       165
#
#     accuracy                           0.07      1041
#    macro avg       0.02      0.25      0.03      1041
# weighted avg       0.00      0.07      0.01      1041
#
#
# 🧪 Evaluation for SN095
#               precision    recall  f1-score   support
#
#            W       0.49      1.00      0.66       419
#         N1/2       0.00      0.00      0.00       273
#           N3       0.00      0.00      0.00       111
#            R       0.00      0.00      0.00        50
#
#     accuracy                           0.49       853
#    macro avg       0.12      0.25      0.16       853
# weighted avg       0.24      0.49      0.32       853
#
#
# 🧪 Evaluation for SN096
#               precision    recall  f1-score   support
#
#            W       0.64      1.00      0.78       455
#         N1/2       0.00      0.00      0.00       128
#           N3       0.00      0.00      0.00        69
#            R       0.00      0.00      0.00        55
#
#     accuracy                           0.64       707
#    macro avg       0.16      0.25      0.20       707
# weighted avg       0.41      0.64      0.50       707
#
#
# 🧪 Evaluation for SN097
#               precision    recall  f1-score   support
#
#            W       0.04      1.00      0.07        37
#         N1/2       0.00      0.00      0.00       595
#           N3       0.00      0.00      0.00       153
#            R       0.00      0.00      0.00       256
#
#     accuracy                           0.04      1041
#    macro avg       0.01      0.25      0.02      1041
# weighted avg       0.00      0.04      0.00      1041
#
#
# 🧪 Evaluation for SN098
#               precision    recall  f1-score   support
#
#            W       0.08      1.00      0.15        71
#         N1/2       0.00      0.00      0.00       524
#           N3       0.00      0.00      0.00       138
#            R       0.00      0.00      0.00       133
#
#     accuracy                           0.08       866
#    macro avg       0.02      0.25      0.04       866
# weighted avg       0.01      0.08      0.01       866
#
#
# 🧪 Evaluation for SN099
#               precision    recall  f1-score   support
#
#            W       0.06      1.00      0.11        48
#         N1/2       0.00      0.00      0.00       394
#           N3       0.00      0.00      0.00       211
#            R       0.00      0.00      0.00       185
#
#     accuracy                           0.06       838
#    macro avg       0.01      0.25      0.03       838
# weighted avg       0.00      0.06      0.01       838
#
#
# 🧪 Evaluation for SN100
#               precision    recall  f1-score   support
#
#            W       0.08      1.00      0.15        72
#         N1/2       0.00      0.00      0.00       424
#           N3       0.00      0.00      0.00       234
#            R       0.00      0.00      0.00       166
#
#     accuracy                           0.08       896
#    macro avg       0.02      0.25      0.04       896
# weighted avg       0.01      0.08      0.01       896
#
#
# 🧪 Evaluation for SN101
#               precision    recall  f1-score   support
#
#            W       0.13      1.00      0.23       116
#         N1/2       0.00      0.00      0.00       467
#           N3       0.00      0.00      0.00       124
#            R       0.00      0.00      0.00       203
#
#     accuracy                           0.13       910
#    macro avg       0.03      0.25      0.06       910
# weighted avg       0.02      0.13      0.03       910
#
#
# 🧪 Evaluation for SN102
#               precision    recall  f1-score   support
#
#            W       0.35      1.00      0.52       292
#         N1/2       0.00      0.00      0.00       382
#           N3       0.00      0.00      0.00        36
#            R       0.00      0.00      0.00       121
#
#     accuracy                           0.35       831
#    macro avg       0.09      0.25      0.13       831
# weighted avg       0.12      0.35      0.18       831
#
#
# 🧪 Evaluation for SN103
#               precision    recall  f1-score   support
#
#            W       0.06      1.00      0.12        61
#         N1/2       0.00      0.00      0.00       452
#           N3       0.00      0.00      0.00       211
#            R       0.00      0.00      0.00       251
#
#     accuracy                           0.06       975
#    macro avg       0.02      0.25      0.03       975
# weighted avg       0.00      0.06      0.01       975
#
#
# 🧪 Evaluation for SN104
#               precision    recall  f1-score   support
#
#            W       0.17      1.00      0.29       168
#         N1/2       0.00      0.00      0.00       597
#           N3       0.00      0.00      0.00       129
#            R       0.00      0.00      0.00       104
#
#     accuracy                           0.17       998
#    macro avg       0.04      0.25      0.07       998
# weighted avg       0.03      0.17      0.05       998
#
#
# 🧪 Evaluation for SN105
#               precision    recall  f1-score   support
#
#            W       0.03      1.00      0.06        26
#         N1/2       0.00      0.00      0.00       412
#           N3       0.00      0.00      0.00       222
#            R       0.00      0.00      0.00       169
#
#     accuracy                           0.03       829
#    macro avg       0.01      0.25      0.02       829
# weighted avg       0.00      0.03      0.00       829
#
#
# 🧪 Evaluation for SN106
#               precision    recall  f1-score   support
#
#            W       0.15      1.00      0.26        98
#         N1/2       0.00      0.00      0.00       365
#           N3       0.00      0.00      0.00       150
#            R       0.00      0.00      0.00        53
#
#     accuracy                           0.15       666
#    macro avg       0.04      0.25      0.06       666
# weighted avg       0.02      0.15      0.04       666
#
#
# 🧪 Evaluation for SN107
#               precision    recall  f1-score   support
#
#            W       0.09      1.00      0.17        68
#         N1/2       0.00      0.00      0.00       476
#           N3       0.00      0.00      0.00       109
#            R       0.00      0.00      0.00        91
#
#     accuracy                           0.09       744
#    macro avg       0.02      0.25      0.04       744
# weighted avg       0.01      0.09      0.02       744
#
#
# 🧪 Evaluation for SN108
#               precision    recall  f1-score   support
#
#            W       0.05      1.00      0.09        41
#         N1/2       0.00      0.00      0.00       493
#           N3       0.00      0.00      0.00       224
#            R       0.00      0.00      0.00       115
#
#     accuracy                           0.05       873
#    macro avg       0.01      0.25      0.02       873
# weighted avg       0.00      0.05      0.00       873
#
#
# 🧪 Evaluation for SN109
#               precision    recall  f1-score   support
#
#            W       0.49      1.00      0.65       376
#         N1/2       0.00      0.00      0.00       192
#           N3       0.00      0.00      0.00       158
#            R       0.00      0.00      0.00        48
#
#     accuracy                           0.49       774
#    macro avg       0.12      0.25      0.16       774
# weighted avg       0.24      0.49      0.32       774
#
#
# 🧪 Evaluation for SN110
#               precision    recall  f1-score   support
#
#            W       0.35      1.00      0.52       331
#         N1/2       0.00      0.00      0.00       342
#           N3       0.00      0.00      0.00       183
#            R       0.00      0.00      0.00        96
#
#     accuracy                           0.35       952
#    macro avg       0.09      0.25      0.13       952
# weighted avg       0.12      0.35      0.18       952
#
#
# 🧪 Evaluation for SN111
#               precision    recall  f1-score   support
#
#            W       0.12      1.00      0.21       126
#         N1/2       0.00      0.00      0.00       632
#           N3       0.00      0.00      0.00       138
#            R       0.00      0.00      0.00       172
#
#     accuracy                           0.12      1068
#    macro avg       0.03      0.25      0.05      1068
# weighted avg       0.01      0.12      0.02      1068
#
#
# 🧪 Evaluation for SN112
#               precision    recall  f1-score   support
#
#            W       0.58      1.00      0.73       483
#         N1/2       0.00      0.00      0.00       273
#           N3       0.00      0.00      0.00        83
#            R       0.00      0.00      0.00         0
#
#     accuracy                           0.58       839
#    macro avg       0.14      0.25      0.18       839
# weighted avg       0.33      0.58      0.42       839
#
#
# 🧪 Evaluation for SN113
#               precision    recall  f1-score   support
#
#            W       0.18      1.00      0.31       159
#         N1/2       0.00      0.00      0.00       403
#           N3       0.00      0.00      0.00       236
#            R       0.00      0.00      0.00        85
#
#     accuracy                           0.18       883
#    macro avg       0.05      0.25      0.08       883
# weighted avg       0.03      0.18      0.05       883
#
#
# 🧪 Evaluation for SN114
#               precision    recall  f1-score   support
#
#            W       0.13      1.00      0.23        77
#         N1/2       0.00      0.00      0.00       352
#           N3       0.00      0.00      0.00        73
#            R       0.00      0.00      0.00        98
#
#     accuracy                           0.13       600
#    macro avg       0.03      0.25      0.06       600
# weighted avg       0.02      0.13      0.03       600
#
#
# 🧪 Evaluation for SN115
#               precision    recall  f1-score   support
#
#            W       0.15      1.00      0.27       130
#         N1/2       0.00      0.00      0.00       454
#           N3       0.00      0.00      0.00        98
#            R       0.00      0.00      0.00       166
#
#     accuracy                           0.15       848
#    macro avg       0.04      0.25      0.07       848
# weighted avg       0.02      0.15      0.04       848
#
#
# 🧪 Evaluation for SN116
#               precision    recall  f1-score   support
#
#            W       0.30      1.00      0.46       236
#         N1/2       0.00      0.00      0.00       330
#           N3       0.00      0.00      0.00       179
#            R       0.00      0.00      0.00        43
#
#     accuracy                           0.30       788
#    macro avg       0.07      0.25      0.12       788
# weighted avg       0.09      0.30      0.14       788
#
#
# 🧪 Evaluation for SN117
#               precision    recall  f1-score   support
#
#            W       0.15      1.00      0.26       113
#         N1/2       0.00      0.00      0.00       341
#           N3       0.00      0.00      0.00       190
#            R       0.00      0.00      0.00       108
#
#     accuracy                           0.15       752
#    macro avg       0.04      0.25      0.07       752
# weighted avg       0.02      0.15      0.04       752
#
#
# 🧪 Evaluation for SN118
#               precision    recall  f1-score   support
#
#            W       0.11      1.00      0.19       106
#         N1/2       0.00      0.00      0.00       505
#           N3       0.00      0.00      0.00       192
#            R       0.00      0.00      0.00       184
#
#     accuracy                           0.11       987
#    macro avg       0.03      0.25      0.05       987
# weighted avg       0.01      0.11      0.02       987
#
#
# 🧪 Evaluation for SN119
#               precision    recall  f1-score   support
#
#            W       0.09      1.00      0.16        80
#         N1/2       0.00      0.00      0.00       465
#           N3       0.00      0.00      0.00       268
#            R       0.00      0.00      0.00        94
#
#     accuracy                           0.09       907
#    macro avg       0.02      0.25      0.04       907
# weighted avg       0.01      0.09      0.01       907
#
#
# 🧪 Evaluation for SN120
#               precision    recall  f1-score   support
#
#            W       0.55      1.00      0.71       446
#         N1/2       0.00      0.00      0.00       165
#           N3       0.00      0.00      0.00       164
#            R       0.00      0.00      0.00        29
#
#     accuracy                           0.55       804
#    macro avg       0.14      0.25      0.18       804
# weighted avg       0.31      0.55      0.40       804
#
#
# 🧪 Evaluation for SN121
#               precision    recall  f1-score   support
#
#            W       0.05      1.00      0.09        52
#         N1/2       0.00      0.00      0.00       409
#           N3       0.00      0.00      0.00       304
#            R       0.00      0.00      0.00       309
#
#     accuracy                           0.05      1074
#    macro avg       0.01      0.25      0.02      1074
# weighted avg       0.00      0.05      0.00      1074
#
#
# 🧪 Evaluation for SN122
#               precision    recall  f1-score   support
#
#            W       0.07      1.00      0.13        57
#         N1/2       0.00      0.00      0.00       370
#           N3       0.00      0.00      0.00       288
#            R       0.00      0.00      0.00       121
#
#     accuracy                           0.07       836
#    macro avg       0.02      0.25      0.03       836
# weighted avg       0.00      0.07      0.01       836
#
#
# 🧪 Evaluation for SN123
#               precision    recall  f1-score   support
#
#            W       0.16      1.00      0.27       115
#         N1/2       0.00      0.00      0.00       258
#           N3       0.00      0.00      0.00       269
#            R       0.00      0.00      0.00        98
#
#     accuracy                           0.16       740
#    macro avg       0.04      0.25      0.07       740
# weighted avg       0.02      0.16      0.04       740
#
#
# 📊 Test Results:
#
# 🧪 Evaluation for SN124
#               precision    recall  f1-score   support
#
#            W       0.18      1.00      0.30       184
#         N1/2       0.00      0.00      0.00       568
#           N3       0.00      0.00      0.00       141
#            R       0.00      0.00      0.00       134
#
#     accuracy                           0.18      1027
#    macro avg       0.04      0.25      0.08      1027
# weighted avg       0.03      0.18      0.05      1027
#
#
# 🧪 Evaluation for SN125
#               precision    recall  f1-score   support
#
#            W       0.00      1.00      0.01         5
#         N1/2       0.00      0.00      0.00       286
#           N3       0.00      0.00      0.00       659
#            R       0.00      0.00      0.00       243
#
#     accuracy                           0.00      1193
#    macro avg       0.00      0.25      0.00      1193
# weighted avg       0.00      0.00      0.00      1193
#
#
# 🧪 Evaluation for SN126
#               precision    recall  f1-score   support
#
#            W       0.36      1.00      0.52       281
#         N1/2       0.00      0.00      0.00       316
#           N3       0.00      0.00      0.00       120
#            R       0.00      0.00      0.00        73
#
#     accuracy                           0.36       790
#    macro avg       0.09      0.25      0.13       790
# weighted avg       0.13      0.36      0.19       790
#
#
# 🧪 Evaluation for SN127
#               precision    recall  f1-score   support
#
#            W       0.16      1.00      0.28       157
#         N1/2       0.00      0.00      0.00       437
#           N3       0.00      0.00      0.00       173
#            R       0.00      0.00      0.00       185
#
#     accuracy                           0.16       952
#    macro avg       0.04      0.25      0.07       952
# weighted avg       0.03      0.16      0.05       952
#
#
# 🧪 Evaluation for SN128
#               precision    recall  f1-score   support
#
#            W       0.08      1.00      0.15        73
#         N1/2       0.00      0.00      0.00       538
#           N3       0.00      0.00      0.00       133
#            R       0.00      0.00      0.00       173
#
#     accuracy                           0.08       917
#    macro avg       0.02      0.25      0.04       917
# weighted avg       0.01      0.08      0.01       917
#
#
# 🧪 Evaluation for SN129
#               precision    recall  f1-score   support
#
#            W       0.07      1.00      0.14        62
#         N1/2       0.00      0.00      0.00       504
#           N3       0.00      0.00      0.00       188
#            R       0.00      0.00      0.00       101
#
#     accuracy                           0.07       855
#    macro avg       0.02      0.25      0.03       855
# weighted avg       0.01      0.07      0.01       855
#
#
# 🧪 Evaluation for SN130
#               precision    recall  f1-score   support
#
#            W       0.07      1.00      0.14        37
#         N1/2       0.00      0.00      0.00       225
#           N3       0.00      0.00      0.00       146
#            R       0.00      0.00      0.00        97
#
#     accuracy                           0.07       505
#    macro avg       0.02      0.25      0.03       505
# weighted avg       0.01      0.07      0.01       505
#
#
# 🧪 Evaluation for SN131
#               precision    recall  f1-score   support
#
#            W       0.12      1.00      0.22       118
#         N1/2       0.00      0.00      0.00       425
#           N3       0.00      0.00      0.00       270
#            R       0.00      0.00      0.00       139
#
#     accuracy                           0.12       952
#    macro avg       0.03      0.25      0.06       952
# weighted avg       0.02      0.12      0.03       952
#
#
# 🧪 Evaluation for SN132
#               precision    recall  f1-score   support
#
#            W       0.07      1.00      0.14        74
#         N1/2       0.00      0.00      0.00       611
#           N3       0.00      0.00      0.00       161
#            R       0.00      0.00      0.00       164
#
#     accuracy                           0.07      1010
#    macro avg       0.02      0.25      0.03      1010
# weighted avg       0.01      0.07      0.01      1010
#
#
# 🧪 Evaluation for SN133
#               precision    recall  f1-score   support
#
#            W       0.37      1.00      0.54       364
#         N1/2       0.00      0.00      0.00       432
#           N3       0.00      0.00      0.00        91
#            R       0.00      0.00      0.00        99
#
#     accuracy                           0.37       986
#    macro avg       0.09      0.25      0.13       986
# weighted avg       0.14      0.37      0.20       986
#
#
# 🧪 Evaluation for SN134
#               precision    recall  f1-score   support
#
#            W       0.13      1.00      0.23       153
#         N1/2       0.00      0.00      0.00       638
#           N3       0.00      0.00      0.00       150
#            R       0.00      0.00      0.00       229
#
#     accuracy                           0.13      1170
#    macro avg       0.03      0.25      0.06      1170
# weighted avg       0.02      0.13      0.03      1170
#
#
# 🧪 Evaluation for SN136
#               precision    recall  f1-score   support
#
#            W       0.04      1.00      0.08        29
#         N1/2       0.00      0.00      0.00       324
#           N3       0.00      0.00      0.00       225
#            R       0.00      0.00      0.00       109
#
#     accuracy                           0.04       687
#    macro avg       0.01      0.25      0.02       687
# weighted avg       0.00      0.04      0.00       687
#
#
# 🧪 Evaluation for SN137
#               precision    recall  f1-score   support
#
#            W       0.21      1.00      0.35       223
#         N1/2       0.00      0.00      0.00       561
#           N3       0.00      0.00      0.00       145
#            R       0.00      0.00      0.00       131
#
#     accuracy                           0.21      1060
#    macro avg       0.05      0.25      0.09      1060
# weighted avg       0.04      0.21      0.07      1060
#
#
# 🧪 Evaluation for SN138
#               precision    recall  f1-score   support
#
#            W       0.06      1.00      0.11        65
#         N1/2       0.00      0.00      0.00       697
#           N3       0.00      0.00      0.00       171
#            R       0.00      0.00      0.00       178
#
#     accuracy                           0.06      1111
#    macro avg       0.01      0.25      0.03      1111
# weighted avg       0.00      0.06      0.01      1111
#
#
# 🧪 Evaluation for SN139
#               precision    recall  f1-score   support
#
#            W       0.22      1.00      0.36       159
#         N1/2       0.00      0.00      0.00       254
#           N3       0.00      0.00      0.00       232
#            R       0.00      0.00      0.00        78
#
#     accuracy                           0.22       723
#    macro avg       0.05      0.25      0.09       723
# weighted avg       0.05      0.22      0.08       723
#
#
# 🧪 Evaluation for SN140
#               precision    recall  f1-score   support
#
#            W       0.27      1.00      0.43       356
#         N1/2       0.00      0.00      0.00       447
#           N3       0.00      0.00      0.00       358
#            R       0.00      0.00      0.00       141
#
#     accuracy                           0.27      1302
#    macro avg       0.07      0.25      0.11      1302
# weighted avg       0.07      0.27      0.12      1302
#
#
# 🧪 Evaluation for SN141
#               precision    recall  f1-score   support
#
#            W       0.07      1.00      0.12        70
#         N1/2       0.00      0.00      0.00       580
#           N3       0.00      0.00      0.00       183
#            R       0.00      0.00      0.00       223
#
#     accuracy                           0.07      1056
#    macro avg       0.02      0.25      0.03      1056
# weighted avg       0.00      0.07      0.01      1056
#
#
# 🧪 Evaluation for SN142
#               precision    recall  f1-score   support
#
#            W       0.22      1.00      0.36       200
#         N1/2       0.00      0.00      0.00       387
#           N3       0.00      0.00      0.00       180
#            R       0.00      0.00      0.00       132
#
#     accuracy                           0.22       899
#    macro avg       0.06      0.25      0.09       899
# weighted avg       0.05      0.22      0.08       899
#
#
# 🧪 Evaluation for SN143
#               precision    recall  f1-score   support
#
#            W       0.36      1.00      0.53       337
#         N1/2       0.00      0.00      0.00       405
#           N3       0.00      0.00      0.00       145
#            R       0.00      0.00      0.00        46
#
#     accuracy                           0.36       933
#    macro avg       0.09      0.25      0.13       933
# weighted avg       0.13      0.36      0.19       933
#
#
# 🧪 Evaluation for SN144
#               precision    recall  f1-score   support
#
#            W       0.02      1.00      0.03        13
#         N1/2       0.00      0.00      0.00       346
#           N3       0.00      0.00      0.00       242
#            R       0.00      0.00      0.00       183
#
#     accuracy                           0.02       784
#    macro avg       0.00      0.25      0.01       784
# weighted avg       0.00      0.02      0.00       784
#
#
# 🧪 Evaluation for SN145
#               precision    recall  f1-score   support
#
#            W       0.24      1.00      0.39       185
#         N1/2       0.00      0.00      0.00       425
#           N3       0.00      0.00      0.00        60
#            R       0.00      0.00      0.00       106
#
#     accuracy                           0.24       776
#    macro avg       0.06      0.25      0.10       776
# weighted avg       0.06      0.24      0.09       776
#
#
# 🧪 Evaluation for SN146
#               precision    recall  f1-score   support
#
#            W       0.53      1.00      0.70       541
#         N1/2       0.00      0.00      0.00       229
#           N3       0.00      0.00      0.00       159
#            R       0.00      0.00      0.00        84
#
#     accuracy                           0.53      1013
#    macro avg       0.13      0.25      0.17      1013
# weighted avg       0.29      0.53      0.37      1013
#
#
# 🧪 Evaluation for SN147
#               precision    recall  f1-score   support
#
#            W       0.07      1.00      0.13        62
#         N1/2       0.00      0.00      0.00       422
#           N3       0.00      0.00      0.00       196
#            R       0.00      0.00      0.00       215
#
#     accuracy                           0.07       895
#    macro avg       0.02      0.25      0.03       895
# weighted avg       0.00      0.07      0.01       895
#
#
# 🧪 Evaluation for SN148
#               precision    recall  f1-score   support
#
#            W       0.02      1.00      0.05        20
#         N1/2       0.00      0.00      0.00       397
#           N3       0.00      0.00      0.00       214
#            R       0.00      0.00      0.00       226
#
#     accuracy                           0.02       857
#    macro avg       0.01      0.25      0.01       857
# weighted avg       0.00      0.02      0.00       857
#
#
# 🧪 Evaluation for SN149
#               precision    recall  f1-score   support
#
#            W       0.09      1.00      0.16        74
#         N1/2       0.00      0.00      0.00       512
#           N3       0.00      0.00      0.00       165
#            R       0.00      0.00      0.00       103
#
#     accuracy                           0.09       854
#    macro avg       0.02      0.25      0.04       854
# weighted avg       0.01      0.09      0.01       854
#
#
# 🧪 Evaluation for SN150
#               precision    recall  f1-score   support
#
#            W       0.00      1.00      0.01         2
#         N1/2       0.00      0.00      0.00       305
#           N3       0.00      0.00      0.00       195
#            R       0.00      0.00      0.00        78
#
#     accuracy                           0.00       580
#    macro avg       0.00      0.25      0.00       580
# weighted avg       0.00      0.00      0.00       580
#
#
# 🧪 Evaluation for SN151
#               precision    recall  f1-score   support
#
#            W       0.22      1.00      0.35       180
#         N1/2       0.00      0.00      0.00       401
#           N3       0.00      0.00      0.00       148
#            R       0.00      0.00      0.00       106
#
#     accuracy                           0.22       835
#    macro avg       0.05      0.25      0.09       835
# weighted avg       0.05      0.22      0.08       835
#
#
# 🧪 Evaluation for SN152
#               precision    recall  f1-score   support
#
#            W       0.10      1.00      0.19       101
#         N1/2       0.00      0.00      0.00       398
#           N3       0.00      0.00      0.00       277
#            R       0.00      0.00      0.00       214
#
#     accuracy                           0.10       990
#    macro avg       0.03      0.25      0.05       990
# weighted avg       0.01      0.10      0.02       990
#
#
# 🧪 Evaluation for SN153
#               precision    recall  f1-score   support
#
#            W       0.01      1.00      0.03        12
#         N1/2       0.00      0.00      0.00       515
#           N3       0.00      0.00      0.00       184
#            R       0.00      0.00      0.00       182
#
#     accuracy                           0.01       893
#    macro avg       0.00      0.25      0.01       893
# weighted avg       0.00      0.01      0.00       893
#
#
# 🧪 Evaluation for SN154
#               precision    recall  f1-score   support
#
#            W       0.09      1.00      0.17        91
#         N1/2       0.00      0.00      0.00       703
#           N3       0.00      0.00      0.00        92
#            R       0.00      0.00      0.00       108
#
#     accuracy                           0.09       994
#    macro avg       0.02      0.25      0.04       994
# weighted avg       0.01      0.09      0.02       994

# %%
model = SleepLSTM()
train_model(model, train_loader, epochs=1)

# 평가 (Validation)
import traceback
print("\n📊 validation Results:")
for sn, (X, y) in val_data.items():
    loader = DataLoader(SleepDataset(X, y), batch_size=16, shuffle=False)
    print(f"\n🧪 Evaluation for {sn} (samples: {len(y)})")
    try:
        evaluate_one_person(model, loader)
    except Exception as e:
        print(f"⚠️ Error evaluating {sn}: {e}")
        traceback.print_exc()

# 평가 (Test)
print("\n📊 Test Results:")
for sn, (X, y) in val_data.items():
    loader = DataLoader(SleepDataset(X, y), batch_size=16, shuffle=False)
    print(f"\n🧪 Evaluation for {sn} (samples: {len(y)})")
    try:
        evaluate_one_person(model, loader)
    except Exception as e:
        print(f"⚠️ Error evaluating {sn}: {e}")
        traceback.print_exc()
# Out:
# Epoch [1/1] Loss: nan Acc: 0.1626
#
# 📊 validation Results:
#
# 🧪 Evaluation for SN094 (samples: 1041)
#               precision    recall  f1-score   support
#
#            W       0.07      1.00      0.13        70
#         N1/2       0.00      0.00      0.00       604
#           N3       0.00      0.00      0.00       202
#            R       0.00      0.00      0.00       165
#
#     accuracy                           0.07      1041
#    macro avg       0.02      0.25      0.03      1041
# weighted avg       0.00      0.07      0.01      1041
#
#
# 🧪 Evaluation for SN095 (samples: 853)
#               precision    recall  f1-score   support
#
#            W       0.49      1.00      0.66       419
#         N1/2       0.00      0.00      0.00       273
#           N3       0.00      0.00      0.00       111
#            R       0.00      0.00      0.00        50
#
#     accuracy                           0.49       853
#    macro avg       0.12      0.25      0.16       853
# weighted avg       0.24      0.49      0.32       853
#
#
# 🧪 Evaluation for SN096 (samples: 707)
#               precision    recall  f1-score   support
#
#            W       0.64      1.00      0.78       455
#         N1/2       0.00      0.00      0.00       128
#           N3       0.00      0.00      0.00        69
#            R       0.00      0.00      0.00        55
#
#     accuracy                           0.64       707
#    macro avg       0.16      0.25      0.20       707
# weighted avg       0.41      0.64      0.50       707
#
#
# 🧪 Evaluation for SN097 (samples: 1041)
#               precision    recall  f1-score   support
#
#            W       0.04      1.00      0.07        37
#         N1/2       0.00      0.00      0.00       595
#           N3       0.00      0.00      0.00       153
#            R       0.00      0.00      0.00       256
#
#     accuracy                           0.04      1041
#    macro avg       0.01      0.25      0.02      1041
# weighted avg       0.00      0.04      0.00      1041
#
#
# 🧪 Evaluation for SN098 (samples: 866)
#               precision    recall  f1-score   support
#
#            W       0.08      1.00      0.15        71
#         N1/2       0.00      0.00      0.00       524
#           N3       0.00      0.00      0.00       138
#            R       0.00      0.00      0.00       133
#
#     accuracy                           0.08       866
#    macro avg       0.02      0.25      0.04       866
# weighted avg       0.01      0.08      0.01       866
#
#
# 🧪 Evaluation for SN099 (samples: 838)
#               precision    recall  f1-score   support
#
#            W       0.06      1.00      0.11        48
#         N1/2       0.00      0.00      0.00       394
#           N3       0.00      0.00      0.00       211
#            R       0.00      0.00      0.00       185
#
#     accuracy                           0.06       838
#    macro avg       0.01      0.25      0.03       838
# weighted avg       0.00      0.06      0.01       838
#
#
# 🧪 Evaluation for SN100 (samples: 896)
#               precision    recall  f1-score   support
#
#            W       0.08      1.00      0.15        72
#         N1/2       0.00      0.00      0.00       424
#           N3       0.00      0.00      0.00       234
#            R       0.00      0.00      0.00       166
#
#     accuracy                           0.08       896
#    macro avg       0.02      0.25      0.04       896
# weighted avg       0.01      0.08      0.01       896
#
#
# 🧪 Evaluation for SN101 (samples: 910)
#               precision    recall  f1-score   support
#
#            W       0.13      1.00      0.23       116
#         N1/2       0.00      0.00      0.00       467
#           N3       0.00      0.00      0.00       124
#            R       0.00      0.00      0.00       203
#
#     accuracy                           0.13       910
#    macro avg       0.03      0.25      0.06       910
# weighted avg       0.02      0.13      0.03       910
#
#
# 🧪 Evaluation for SN102 (samples: 831)
#               precision    recall  f1-score   support
#
#            W       0.35      1.00      0.52       292
#         N1/2       0.00      0.00      0.00       382
#           N3       0.00      0.00      0.00        36
#            R       0.00      0.00      0.00       121
#
#     accuracy                           0.35       831
#    macro avg       0.09      0.25      0.13       831
# weighted avg       0.12      0.35      0.18       831
#
#
# 🧪 Evaluation for SN103 (samples: 975)
#               precision    recall  f1-score   support
#
#            W       0.06      1.00      0.12        61
#         N1/2       0.00      0.00      0.00       452
#           N3       0.00      0.00      0.00       211
#            R       0.00      0.00      0.00       251
#
#     accuracy                           0.06       975
#    macro avg       0.02      0.25      0.03       975
# weighted avg       0.00      0.06      0.01       975
#
#
# 🧪 Evaluation for SN104 (samples: 998)
#               precision    recall  f1-score   support
#
#            W       0.17      1.00      0.29       168
#         N1/2       0.00      0.00      0.00       597
#           N3       0.00      0.00      0.00       129
#            R       0.00      0.00      0.00       104
#
#     accuracy                           0.17       998
#    macro avg       0.04      0.25      0.07       998
# weighted avg       0.03      0.17      0.05       998
#
#
# 🧪 Evaluation for SN105 (samples: 829)
#               precision    recall  f1-score   support
#
#            W       0.03      1.00      0.06        26
#         N1/2       0.00      0.00      0.00       412
#           N3       0.00      0.00      0.00       222
#            R       0.00      0.00      0.00       169
#
#     accuracy                           0.03       829
#    macro avg       0.01      0.25      0.02       829
# weighted avg       0.00      0.03      0.00       829
#
#
# 🧪 Evaluation for SN106 (samples: 666)
#               precision    recall  f1-score   support
#
#            W       0.15      1.00      0.26        98
#         N1/2       0.00      0.00      0.00       365
#           N3       0.00      0.00      0.00       150
#            R       0.00      0.00      0.00        53
#
#     accuracy                           0.15       666
#    macro avg       0.04      0.25      0.06       666
# weighted avg       0.02      0.15      0.04       666
#
#
# 🧪 Evaluation for SN107 (samples: 744)
#               precision    recall  f1-score   support
#
#            W       0.09      1.00      0.17        68
#         N1/2       0.00      0.00      0.00       476
#           N3       0.00      0.00      0.00       109
#            R       0.00      0.00      0.00        91
#
#     accuracy                           0.09       744
#    macro avg       0.02      0.25      0.04       744
# weighted avg       0.01      0.09      0.02       744
#
#
# 🧪 Evaluation for SN108 (samples: 873)
#               precision    recall  f1-score   support
#
#            W       0.05      1.00      0.09        41
#         N1/2       0.00      0.00      0.00       493
#           N3       0.00      0.00      0.00       224
#            R       0.00      0.00      0.00       115
#
#     accuracy                           0.05       873
#    macro avg       0.01      0.25      0.02       873
# weighted avg       0.00      0.05      0.00       873
#
#
# 🧪 Evaluation for SN109 (samples: 774)
#               precision    recall  f1-score   support
#
#            W       0.49      1.00      0.65       376
#         N1/2       0.00      0.00      0.00       192
#           N3       0.00      0.00      0.00       158
#            R       0.00      0.00      0.00        48
#
#     accuracy                           0.49       774
#    macro avg       0.12      0.25      0.16       774
# weighted avg       0.24      0.49      0.32       774
#
#
# 🧪 Evaluation for SN110 (samples: 952)
#               precision    recall  f1-score   support
#
#            W       0.35      1.00      0.52       331
#         N1/2       0.00      0.00      0.00       342
#           N3       0.00      0.00      0.00       183
#            R       0.00      0.00      0.00        96
#
#     accuracy                           0.35       952
#    macro avg       0.09      0.25      0.13       952
# weighted avg       0.12      0.35      0.18       952
#
#
# 🧪 Evaluation for SN111 (samples: 1068)
#               precision    recall  f1-score   support
#
#            W       0.12      1.00      0.21       126
#         N1/2       0.00      0.00      0.00       632
#           N3       0.00      0.00      0.00       138
#            R       0.00      0.00      0.00       172
#
#     accuracy                           0.12      1068
#    macro avg       0.03      0.25      0.05      1068
# weighted avg       0.01      0.12      0.02      1068
#
#
# 🧪 Evaluation for SN112 (samples: 839)
#               precision    recall  f1-score   support
#
#            W       0.58      1.00      0.73       483
#         N1/2       0.00      0.00      0.00       273
#           N3       0.00      0.00      0.00        83
#            R       0.00      0.00      0.00         0
#
#     accuracy                           0.58       839
#    macro avg       0.14      0.25      0.18       839
# weighted avg       0.33      0.58      0.42       839
#
#
# 🧪 Evaluation for SN113 (samples: 883)
#               precision    recall  f1-score   support
#
#            W       0.18      1.00      0.31       159
#         N1/2       0.00      0.00      0.00       403
#           N3       0.00      0.00      0.00       236
#            R       0.00      0.00      0.00        85
#
#     accuracy                           0.18       883
#    macro avg       0.05      0.25      0.08       883
# weighted avg       0.03      0.18      0.05       883
#
#
# 🧪 Evaluation for SN114 (samples: 600)
#               precision    recall  f1-score   support
#
#            W       0.13      1.00      0.23        77
#         N1/2       0.00      0.00      0.00       352
#           N3       0.00      0.00      0.00        73
#            R       0.00      0.00      0.00        98
#
#     accuracy                           0.13       600
#    macro avg       0.03      0.25      0.06       600
# weighted avg       0.02      0.13      0.03       600
#
#
# 🧪 Evaluation for SN115 (samples: 848)
#               precision    recall  f1-score   support
#
#            W       0.15      1.00      0.27       130
#         N1/2       0.00      0.00      0.00       454
#           N3       0.00      0.00      0.00        98
#            R       0.00      0.00      0.00       166
#
#     accuracy                           0.15       848
#    macro avg       0.04      0.25      0.07       848
# weighted avg       0.02      0.15      0.04       848
#
#
# 🧪 Evaluation for SN116 (samples: 788)
#               precision    recall  f1-score   support
#
#            W       0.30      1.00      0.46       236
#         N1/2       0.00      0.00      0.00       330
#           N3       0.00      0.00      0.00       179
#            R       0.00      0.00      0.00        43
#
#     accuracy                           0.30       788
#    macro avg       0.07      0.25      0.12       788
# weighted avg       0.09      0.30      0.14       788
#
#
# 🧪 Evaluation for SN117 (samples: 752)
#               precision    recall  f1-score   support
#
#            W       0.15      1.00      0.26       113
#         N1/2       0.00      0.00      0.00       341
#           N3       0.00      0.00      0.00       190
#            R       0.00      0.00      0.00       108
#
#     accuracy                           0.15       752
#    macro avg       0.04      0.25      0.07       752
# weighted avg       0.02      0.15      0.04       752
#
#
# 🧪 Evaluation for SN118 (samples: 987)
#               precision    recall  f1-score   support
#
#            W       0.11      1.00      0.19       106
#         N1/2       0.00      0.00      0.00       505
#           N3       0.00      0.00      0.00       192
#            R       0.00      0.00      0.00       184
#
#     accuracy                           0.11       987
#    macro avg       0.03      0.25      0.05       987
# weighted avg       0.01      0.11      0.02       987
#
#
# 🧪 Evaluation for SN119 (samples: 907)
#               precision    recall  f1-score   support
#
#            W       0.09      1.00      0.16        80
#         N1/2       0.00      0.00      0.00       465
#           N3       0.00      0.00      0.00       268
#            R       0.00      0.00      0.00        94
#
#     accuracy                           0.09       907
#    macro avg       0.02      0.25      0.04       907
# weighted avg       0.01      0.09      0.01       907
#
#
# 🧪 Evaluation for SN120 (samples: 804)
#               precision    recall  f1-score   support
#
#            W       0.55      1.00      0.71       446
#         N1/2       0.00      0.00      0.00       165
#           N3       0.00      0.00      0.00       164
#            R       0.00      0.00      0.00        29
#
#     accuracy                           0.55       804
#    macro avg       0.14      0.25      0.18       804
# weighted avg       0.31      0.55      0.40       804
#
#
# 🧪 Evaluation for SN121 (samples: 1074)
#               precision    recall  f1-score   support
#
#            W       0.05      1.00      0.09        52
#         N1/2       0.00      0.00      0.00       409
#           N3       0.00      0.00      0.00       304
#            R       0.00      0.00      0.00       309
#
#     accuracy                           0.05      1074
#    macro avg       0.01      0.25      0.02      1074
# weighted avg       0.00      0.05      0.00      1074
#
#
# 🧪 Evaluation for SN122 (samples: 836)
#               precision    recall  f1-score   support
#
#            W       0.07      1.00      0.13        57
#         N1/2       0.00      0.00      0.00       370
#           N3       0.00      0.00      0.00       288
#            R       0.00      0.00      0.00       121
#
#     accuracy                           0.07       836
#    macro avg       0.02      0.25      0.03       836
# weighted avg       0.00      0.07      0.01       836
#
#
# 🧪 Evaluation for SN123 (samples: 740)
#               precision    recall  f1-score   support
#
#            W       0.16      1.00      0.27       115
#         N1/2       0.00      0.00      0.00       258
#           N3       0.00      0.00      0.00       269
#            R       0.00      0.00      0.00        98
#
#     accuracy                           0.16       740
#    macro avg       0.04      0.25      0.07       740
# weighted avg       0.02      0.16      0.04       740
#
#
# 📊 Test Results:
#
# 🧪 Evaluation for SN094 (samples: 1041)
#               precision    recall  f1-score   support
#
#            W       0.07      1.00      0.13        70
#         N1/2       0.00      0.00      0.00       604
#           N3       0.00      0.00      0.00       202
#            R       0.00      0.00      0.00       165
#
#     accuracy                           0.07      1041
#    macro avg       0.02      0.25      0.03      1041
# weighted avg       0.00      0.07      0.01      1041
#
#
# 🧪 Evaluation for SN095 (samples: 853)
#               precision    recall  f1-score   support
#
#            W       0.49      1.00      0.66       419
#         N1/2       0.00      0.00      0.00       273
#           N3       0.00      0.00      0.00       111
#            R       0.00      0.00      0.00        50
#
#     accuracy                           0.49       853
#    macro avg       0.12      0.25      0.16       853
# weighted avg       0.24      0.49      0.32       853
#
#
# 🧪 Evaluation for SN096 (samples: 707)
#               precision    recall  f1-score   support
#
#            W       0.64      1.00      0.78       455
#         N1/2       0.00      0.00      0.00       128
#           N3       0.00      0.00      0.00        69
#            R       0.00      0.00      0.00        55
#
#     accuracy                           0.64       707
#    macro avg       0.16      0.25      0.20       707
# weighted avg       0.41      0.64      0.50       707
#
#
# 🧪 Evaluation for SN097 (samples: 1041)
#               precision    recall  f1-score   support
#
#            W       0.04      1.00      0.07        37
#         N1/2       0.00      0.00      0.00       595
#           N3       0.00      0.00      0.00       153
#            R       0.00      0.00      0.00       256
#
#     accuracy                           0.04      1041
#    macro avg       0.01      0.25      0.02      1041
# weighted avg       0.00      0.04      0.00      1041
#
#
# 🧪 Evaluation for SN098 (samples: 866)
#               precision    recall  f1-score   support
#
#            W       0.08      1.00      0.15        71
#         N1/2       0.00      0.00      0.00       524
#           N3       0.00      0.00      0.00       138
#            R       0.00      0.00      0.00       133
#
#     accuracy                           0.08       866
#    macro avg       0.02      0.25      0.04       866
# weighted avg       0.01      0.08      0.01       866
#
#
# 🧪 Evaluation for SN099 (samples: 838)
#               precision    recall  f1-score   support
#
#            W       0.06      1.00      0.11        48
#         N1/2       0.00      0.00      0.00       394
#           N3       0.00      0.00      0.00       211
#            R       0.00      0.00      0.00       185
#
#     accuracy                           0.06       838
#    macro avg       0.01      0.25      0.03       838
# weighted avg       0.00      0.06      0.01       838
#
#
# 🧪 Evaluation for SN100 (samples: 896)
#               precision    recall  f1-score   support
#
#            W       0.08      1.00      0.15        72
#         N1/2       0.00      0.00      0.00       424
#           N3       0.00      0.00      0.00       234
#            R       0.00      0.00      0.00       166
#
#     accuracy                           0.08       896
#    macro avg       0.02      0.25      0.04       896
# weighted avg       0.01      0.08      0.01       896
#
#
# 🧪 Evaluation for SN101 (samples: 910)
#               precision    recall  f1-score   support
#
#            W       0.13      1.00      0.23       116
#         N1/2       0.00      0.00      0.00       467
#           N3       0.00      0.00      0.00       124
#            R       0.00      0.00      0.00       203
#
#     accuracy                           0.13       910
#    macro avg       0.03      0.25      0.06       910
# weighted avg       0.02      0.13      0.03       910
#
#
# 🧪 Evaluation for SN102 (samples: 831)
#               precision    recall  f1-score   support
#
#            W       0.35      1.00      0.52       292
#         N1/2       0.00      0.00      0.00       382
#           N3       0.00      0.00      0.00        36
#            R       0.00      0.00      0.00       121
#
#     accuracy                           0.35       831
#    macro avg       0.09      0.25      0.13       831
# weighted avg       0.12      0.35      0.18       831
#
#
# 🧪 Evaluation for SN103 (samples: 975)
#               precision    recall  f1-score   support
#
#            W       0.06      1.00      0.12        61
#         N1/2       0.00      0.00      0.00       452
#           N3       0.00      0.00      0.00       211
#            R       0.00      0.00      0.00       251
#
#     accuracy                           0.06       975
#    macro avg       0.02      0.25      0.03       975
# weighted avg       0.00      0.06      0.01       975
#
#
# 🧪 Evaluation for SN104 (samples: 998)
#               precision    recall  f1-score   support
#
#            W       0.17      1.00      0.29       168
#         N1/2       0.00      0.00      0.00       597
#           N3       0.00      0.00      0.00       129
#            R       0.00      0.00      0.00       104
#
#     accuracy                           0.17       998
#    macro avg       0.04      0.25      0.07       998
# weighted avg       0.03      0.17      0.05       998
#
#
# 🧪 Evaluation for SN105 (samples: 829)
#               precision    recall  f1-score   support
#
#            W       0.03      1.00      0.06        26
#         N1/2       0.00      0.00      0.00       412
#           N3       0.00      0.00      0.00       222
#            R       0.00      0.00      0.00       169
#
#     accuracy                           0.03       829
#    macro avg       0.01      0.25      0.02       829
# weighted avg       0.00      0.03      0.00       829
#
#
# 🧪 Evaluation for SN106 (samples: 666)
#               precision    recall  f1-score   support
#
#            W       0.15      1.00      0.26        98
#         N1/2       0.00      0.00      0.00       365
#           N3       0.00      0.00      0.00       150
#            R       0.00      0.00      0.00        53
#
#     accuracy                           0.15       666
#    macro avg       0.04      0.25      0.06       666
# weighted avg       0.02      0.15      0.04       666
#
#
# 🧪 Evaluation for SN107 (samples: 744)
#               precision    recall  f1-score   support
#
#            W       0.09      1.00      0.17        68
#         N1/2       0.00      0.00      0.00       476
#           N3       0.00      0.00      0.00       109
#            R       0.00      0.00      0.00        91
#
#     accuracy                           0.09       744
#    macro avg       0.02      0.25      0.04       744
# weighted avg       0.01      0.09      0.02       744
#
#
# 🧪 Evaluation for SN108 (samples: 873)
#               precision    recall  f1-score   support
#
#            W       0.05      1.00      0.09        41
#         N1/2       0.00      0.00      0.00       493
#           N3       0.00      0.00      0.00       224
#            R       0.00      0.00      0.00       115
#
#     accuracy                           0.05       873
#    macro avg       0.01      0.25      0.02       873
# weighted avg       0.00      0.05      0.00       873
#
#
# 🧪 Evaluation for SN109 (samples: 774)
#               precision    recall  f1-score   support
#
#            W       0.49      1.00      0.65       376
#         N1/2       0.00      0.00      0.00       192
#           N3       0.00      0.00      0.00       158
#            R       0.00      0.00      0.00        48
#
#     accuracy                           0.49       774
#    macro avg       0.12      0.25      0.16       774
# weighted avg       0.24      0.49      0.32       774
#
#
# 🧪 Evaluation for SN110 (samples: 952)
#               precision    recall  f1-score   support
#
#            W       0.35      1.00      0.52       331
#         N1/2       0.00      0.00      0.00       342
#           N3       0.00      0.00      0.00       183
#            R       0.00      0.00      0.00        96
#
#     accuracy                           0.35       952
#    macro avg       0.09      0.25      0.13       952
# weighted avg       0.12      0.35      0.18       952
#
#
# 🧪 Evaluation for SN111 (samples: 1068)
#               precision    recall  f1-score   support
#
#            W       0.12      1.00      0.21       126
#         N1/2       0.00      0.00      0.00       632
#           N3       0.00      0.00      0.00       138
#            R       0.00      0.00      0.00       172
#
#     accuracy                           0.12      1068
#    macro avg       0.03      0.25      0.05      1068
# weighted avg       0.01      0.12      0.02      1068
#
#
# 🧪 Evaluation for SN112 (samples: 839)
#               precision    recall  f1-score   support
#
#            W       0.58      1.00      0.73       483
#         N1/2       0.00      0.00      0.00       273
#           N3       0.00      0.00      0.00        83
#            R       0.00      0.00      0.00         0
#
#     accuracy                           0.58       839
#    macro avg       0.14      0.25      0.18       839
# weighted avg       0.33      0.58      0.42       839
#
#
# 🧪 Evaluation for SN113 (samples: 883)
#               precision    recall  f1-score   support
#
#            W       0.18      1.00      0.31       159
#         N1/2       0.00      0.00      0.00       403
#           N3       0.00      0.00      0.00       236
#            R       0.00      0.00      0.00        85
#
#     accuracy                           0.18       883
#    macro avg       0.05      0.25      0.08       883
# weighted avg       0.03      0.18      0.05       883
#
#
# 🧪 Evaluation for SN114 (samples: 600)
#               precision    recall  f1-score   support
#
#            W       0.13      1.00      0.23        77
#         N1/2       0.00      0.00      0.00       352
#           N3       0.00      0.00      0.00        73
#            R       0.00      0.00      0.00        98
#
#     accuracy                           0.13       600
#    macro avg       0.03      0.25      0.06       600
# weighted avg       0.02      0.13      0.03       600
#
#
# 🧪 Evaluation for SN115 (samples: 848)
#               precision    recall  f1-score   support
#
#            W       0.15      1.00      0.27       130
#         N1/2       0.00      0.00      0.00       454
#           N3       0.00      0.00      0.00        98
#            R       0.00      0.00      0.00       166
#
#     accuracy                           0.15       848
#    macro avg       0.04      0.25      0.07       848
# weighted avg       0.02      0.15      0.04       848
#
#
# 🧪 Evaluation for SN116 (samples: 788)
#               precision    recall  f1-score   support
#
#            W       0.30      1.00      0.46       236
#         N1/2       0.00      0.00      0.00       330
#           N3       0.00      0.00      0.00       179
#            R       0.00      0.00      0.00        43
#
#     accuracy                           0.30       788
#    macro avg       0.07      0.25      0.12       788
# weighted avg       0.09      0.30      0.14       788
#
#
# 🧪 Evaluation for SN117 (samples: 752)
#               precision    recall  f1-score   support
#
#            W       0.15      1.00      0.26       113
#         N1/2       0.00      0.00      0.00       341
#           N3       0.00      0.00      0.00       190
#            R       0.00      0.00      0.00       108
#
#     accuracy                           0.15       752
#    macro avg       0.04      0.25      0.07       752
# weighted avg       0.02      0.15      0.04       752
#
#
# 🧪 Evaluation for SN118 (samples: 987)
#               precision    recall  f1-score   support
#
#            W       0.11      1.00      0.19       106
#         N1/2       0.00      0.00      0.00       505
#           N3       0.00      0.00      0.00       192
#            R       0.00      0.00      0.00       184
#
#     accuracy                           0.11       987
#    macro avg       0.03      0.25      0.05       987
# weighted avg       0.01      0.11      0.02       987
#
#
# 🧪 Evaluation for SN119 (samples: 907)
#               precision    recall  f1-score   support
#
#            W       0.09      1.00      0.16        80
#         N1/2       0.00      0.00      0.00       465
#           N3       0.00      0.00      0.00       268
#            R       0.00      0.00      0.00        94
#
#     accuracy                           0.09       907
#    macro avg       0.02      0.25      0.04       907
# weighted avg       0.01      0.09      0.01       907
#
#
# 🧪 Evaluation for SN120 (samples: 804)
#               precision    recall  f1-score   support
#
#            W       0.55      1.00      0.71       446
#         N1/2       0.00      0.00      0.00       165
#           N3       0.00      0.00      0.00       164
#            R       0.00      0.00      0.00        29
#
#     accuracy                           0.55       804
#    macro avg       0.14      0.25      0.18       804
# weighted avg       0.31      0.55      0.40       804
#
#
# 🧪 Evaluation for SN121 (samples: 1074)
#               precision    recall  f1-score   support
#
#            W       0.05      1.00      0.09        52
#         N1/2       0.00      0.00      0.00       409
#           N3       0.00      0.00      0.00       304
#            R       0.00      0.00      0.00       309
#
#     accuracy                           0.05      1074
#    macro avg       0.01      0.25      0.02      1074
# weighted avg       0.00      0.05      0.00      1074
#
#
# 🧪 Evaluation for SN122 (samples: 836)
#               precision    recall  f1-score   support
#
#            W       0.07      1.00      0.13        57
#         N1/2       0.00      0.00      0.00       370
#           N3       0.00      0.00      0.00       288
#            R       0.00      0.00      0.00       121
#
#     accuracy                           0.07       836
#    macro avg       0.02      0.25      0.03       836
# weighted avg       0.00      0.07      0.01       836
#
#
# 🧪 Evaluation for SN123 (samples: 740)
#               precision    recall  f1-score   support
#
#            W       0.16      1.00      0.27       115
#         N1/2       0.00      0.00      0.00       258
#           N3       0.00      0.00      0.00       269
#            R       0.00      0.00      0.00        98
#
#     accuracy                           0.16       740
#    macro avg       0.04      0.25      0.07       740
# weighted avg       0.02      0.16      0.04       740
